# %%
### we will import the usedcars.csv file

# %%
import numpy as np
import pandas as pd

# %%
file_path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv'
# !wget "$file_path" -O "auto.csv"
file_name="auto.csv"
# Out:
# --2026-02-15 18:06:52--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24916 (24K) [text/csv]
# Saving to: ‘auto.csv’
#
# auto.csv            100%[===================>]  24.33K  --.-KB/s    in 0.002s
#
# 2026-02-15 18:06:52 (15.7 MB/s) - ‘auto.csv’ saved [24916/24916]

# %%
df=pd.read_csv("auto.csv")
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
df.head(5)
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
df.tail(5)
# Out:
#      3   ? alfa-romero     gas    std   two convertible  rwd  front   88.6  \
# 199 -1  95       volvo     gas    std  four       sedan  rwd  front  109.1
# 200 -1  95       volvo     gas  turbo  four       sedan  rwd  front  109.1
# 201 -1  95       volvo     gas    std  four       sedan  rwd  front  109.1
# 202 -1  95       volvo  diesel  turbo  four       sedan  rwd  front  109.1
# 203 -1  95       volvo     gas  turbo  four       sedan  rwd  front  109.1
#
#      ...  130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 199  ...  141  mpfi  3.78  3.15   9.5  114  5400  23  28  16845
# 200  ...  141  mpfi  3.78  3.15   8.7  160  5300  19  25  19045
# 201  ...  173  mpfi  3.58  2.87   8.8  134  5500  18  23  21485
# 202  ...  145   idi  3.01  3.40  23.0  106  4800  26  27  22470
# 203  ...  141  mpfi  3.78  3.15   9.5  114  5400  19  25  22625
#
# [5 rows x 26 columns]

# %%
## adding headers

# %%
# create headers list
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", headers)
# Out:
# headers
#  ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
df.columns=headers
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           1                 ?  alfa-romero       gas        std
# 2           2               164         audi       gas        std
# 3           2               164         audi       gas        std
# 4           2                 ?         audi       gas        std
# 5           1               158         audi       gas        std
# 6           1                 ?         audi       gas        std
# 7           1               158         audi       gas      turbo
# 8           0                 ?         audi       gas      turbo
# 9           2               192          bmw       gas        std
# 10          0               192          bmw       gas        std
# 11          0               188          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
df1=df.replace("?",np.nan)
df1
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
## count the missing values

# %%
df1.isnull().sum()
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
missing_price_rows
# Out:
#      symboling normalized-losses     make fuel-type aspiration num-of-doors  \
# 8            0               NaN     audi       gas      turbo          two
# 43           1               NaN    isuzu       gas        std          two
# 44           0               NaN    isuzu       gas        std         four
# 128          1               NaN  porsche       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 8    hatchback          4wd           front        99.5  ...          131
# 43       sedan          fwd           front        94.5  ...           90
# 44       sedan          fwd           front        94.5  ...           90
# 128  hatchback          rwd           front        98.4  ...          203
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 8           mpfi  3.13    3.40               7.0        160      5500
# 43          2bbl  3.03    3.11               9.6         70      5400
# ...

# %%
## to fidn which rows have the no data

# %%
missing_stroke_rows = df1[df1['stroke'].isnull()]
missing_stroke_rows
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 54          3               150  mazda       gas        std          two
# 55          3               150  mazda       gas        std          two
# 56          3               150  mazda       gas        std          two
# 57          3               150  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 54  hatchback          rwd           front        95.3  ...           70
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 57  hatchback          rwd           front        95.3  ...           80
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 54         4bbl   NaN     NaN               9.4        101      6000       17
# ...

# %%
missing_price_rows
# Out:
#      symboling normalized-losses     make fuel-type aspiration num-of-doors  \
# 8            0               NaN     audi       gas      turbo          two
# 43           1               NaN    isuzu       gas        std          two
# 44           0               NaN    isuzu       gas        std         four
# 128          1               NaN  porsche       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 8    hatchback          4wd           front        99.5  ...          131
# 43       sedan          fwd           front        94.5  ...           90
# 44       sedan          fwd           front        94.5  ...           90
# 128  hatchback          rwd           front        98.4  ...          203
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 8           mpfi  3.13    3.40               7.0        160      5500
# 43          2bbl  3.03    3.11               9.6         70      5400
# ...

# %%
missing_num_of_doors_rows = df1[df1['num-of-doors'].isnull()]
missing_num_of_doors_rows
# Out:
#     symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 26          1               148  dodge       gas      turbo          NaN
# 62          0               NaN  mazda    diesel        std          NaN
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 26      sedan          fwd           front        93.7  ...           98
# 62      sedan          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 26         mpfi  3.03    3.39               7.6        102      5500       24
# 62          idi  3.39    3.39              22.7         64      4650       36
#
#    highway-mpg  price
# 26          30   8558
# 62          42  10795
#
# [2 rows x 26 columns]

# %%
df1['price'] = pd.to_numeric(df1['price'], errors='coerce')
df1 = df1.dropna(subset=["price"])
df1.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
# 6          1                 ?         audi       gas        std         four
# 7          1               158         audi       gas      turbo         four
# 8          0                 ?         audi       gas      turbo          two
# 9          2               192          bmw       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# # Task
# Provide the row indices where the 'price' column has missing values.

# %% [markdown]
# ## Identify Rows with Missing Price
#
# ### Subtask:
# Filter the DataFrame `df1` to find all rows where the 'price' column has a missing value (NaN) and display their indices.

# %% [markdown]
# **Reasoning**:
# To identify rows with missing 'price' values, I will filter the DataFrame `df1` where the 'price' column is null and then display their indices.

# %%
missing_price_rows = df1[df1['price'].isnull()]
print("Indices of rows with missing 'price':")
print(missing_price_rows.index.tolist())
# Out:
# Indices of rows with missing 'price':
# [8, 43, 44, 128]

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide the row indices where the 'price' column has missing values.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The row indices where the 'price' column has missing values are `[8, 43, 44, 128]`.
#
# ### Data Analysis Key Findings
# *   The 'price' column in the DataFrame `df1` has missing values (NaN) at row indices 8, 43, 44, and 128.
#
# ### Insights or Next Steps
# *   Investigate the reason for missing values in the 'price' column for these specific rows.
# *   Decide on an appropriate strategy to handle these missing 'price' values, such as imputation (e.g., mean, median, mode) or removal of the affected rows, depending on the downstream analysis requirements and the nature of the data.
