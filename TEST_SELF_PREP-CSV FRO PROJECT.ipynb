# %% [markdown]
# TESTING ON SELF PREPARED CSV FOR THE WOMEN SCHOLARSHIP AND FINANCE PROJECT

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/women.csv  - Sheet1.csv")

# %%
df.head()
# Out:
#                                                title  education_level  \
# 0                AICTE Pragati Scholarship for Girls   Degree/Diploma
# 1  PG Indira Gandhi Scholarship for Single Girl C...     Postgraduate
# 2            Begum Hazrat Mahal National Scholarship    Class 9 to 12
# 3                          INSPIRE Scholarship (SHE)    Undergraduate
# 4           L'Oreal India For Young Women in Science  Class 12 Passed
#
#                      field_of_study country state income_limit  \
# 0    Technical (Engg, Pharma, etc.)   India   All    ₹8,00,000
# 1  Non-Professional (MA, MSc, etc.)   India   All     No Limit
# 2                  School Education   India   All    ₹2,00,000
# 3          Basic & Natural Sciences   India   All     No Limit
# 4              Science/Medical/Engg   India   All    ₹4,00,000
#
#                category                                        description  \
# 0                 Women  Financial aid for girls in 1st year of technic...
# ...

# %%
df.columns
# Out:
# Index(['title', 'education_level', 'field_of_study', 'country', 'state',
#        'income_limit', 'category', 'description', 'deadline',
#        'application_link'],
#       dtype='object')
